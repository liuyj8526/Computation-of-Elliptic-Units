# %%
#N prime. The basis used will be [inf]-[1/N], [inf]-[2/N], ... , [inf]-[floor(N/2)/N]
#N = 4. Basis used [inf]-[1/N]

class Gamma:
    def __init__(self, a, c):      #given numerator and denominator, construct rest of matrix
        """Attributes defined for Gamma:
        a,b,c,d: The matrix coefficients
        num,denom: Numerator and denomnator that generates Gamma by 4.1. Denominator recorded has been divided by N.  
        coeff: +1 or -1, + if c*d >0, - if c*d<0
        x: The numerator in the basis element [inf]-[x/N]
        """
        if c < 0:
            a, c = -a, -c
        self.num = int(a)
        self.denom = int(c)
        
#         if c==N and a>=1 and a<=N-1:
#             self.a = 1
#             self.b = 0
#             self.c = 0
#             self.d = 1
#             self.coeff = 1
#             self.x = a
        
        if c==0:					#case of c = 0 is the infinity case
            self.a = 0
            self.b = 0
            self.c = 0
            self.d = 0				#d will never equal 0 unless its infinity, so this is what we can use to check infinity
            self.coeff = 0
            self.x = 0
        else:
            base = max(N*c,-N*c)
            d = ""
   
            #If N=4, change to =1, else =x. 
            if N == 4:
                d = a.inverse_mod(base)
                if d > base/2: 
                    d -= base
                b = (a*d - 1)/(N*c)
                self.x = 1
            else:
                d = a.inverse_mod(base) - base
                b = (a*d - 1)/(N*c)
                self.x = max(round(abs(d/c))-1, 1)								#x is not the unique choice 
                
            if c*d > 0:												#second matrix in 4.1
                self.a = int(a-N*b)
                self.b = int(b)
                self.c = int(N*c-N*d)
                self.d = int(d)
                self.coeff = 1
            else:													#first matrix
                self.a = int(a)
                self.b = int(b)
                self.c = int(N*c)
                self.d = int(d)
                self.coeff = -1
    
    def __str__(self):     #for print statements
        return (str(self.a) + " " + str(self.b) + " " + str(self.c) + " " + str(self.d))
    
def getGammas(num, denom):			#returns an array of every gamma used
    a = []							
    gam = Gamma(num, (denom/N))			#constructs the first gamma given the fraction
    print(gam)
    a.append(gam)
    return getGammasHelper(gam, a)		#sends to the recursive function
    
def getGammasHelper(prev, gammas):		
    if prev.d == 0:					#if infinity, we are done
        return gammas				
    else:						
        if prev.denom*prev.d > 0:					#second matrix case
            num = prev.num*prev.x - prev.b*N  					#create new fraction
            denom = prev.denom*prev.x*N - prev.d*N
            gam = Gamma(num, (denom/N))					#create new matrix
            print(gam)
            gammas.append(gam)
            return getGammasHelper(gam, gammas)			#run it again
        else:
            num = prev.num*prev.x + prev.b*N
            denom = prev.denom*prev.x*N + prev.d*N
            gam = Gamma(num, (denom/N))
            print(gam)
            gammas.append(gam)
            return getGammasHelper(gam, gammas)

# %%
if __name__ == '__main__' and '__file__' not in globals():        
    N = 5
    a = 181
    b = 200
    t = getGammas(a,b)[:-1]  
    decom = "[inf]-" + "[" + str(a) + "/" + str(b) + "] = " + "\n"
    for gamma in t:
        try:
            print((gamma.a+0)/(gamma.c),(gamma.a*gamma.x+N*gamma.b)/(gamma.c*gamma.x+N*gamma.d))
        except:
            print("0")
        decom += str(gamma.coeff) + "Matrix(" + str(gamma) + ")" + "([inf]-" + "[" + str(gamma.x) + "/" + str(N) + "])" + "\n"
    print(decom)
# Out:
# 181 -162 200 -179
# switch
# 267 -124 295 -137
# switch
# 353 -229 390 -253
# switch
# 439 -105 485 -116
# switch
# 86 -67 95 -74
# switch
# 77 -29 85 -32
# switch
# 68 -39 75 -43
# switch
# 59 -10 65 -11
# 9 -1 10 -1
# 4 -1 5 -1
# 0 0 0 0
# 181/200 267/295
# 267/295 353/390
# 353/390 439/485
# 439/485 86/95
# 86/95 77/85
# 77/85 68/75
# 68/75 59/65
# 59/65 9/10
# 9/10 4/5
# 0
# [inf]-[181/200] =
# -1Matrix(181 -162 200 -179)([inf]-[3/5])
# -1Matrix(267 -124 295 -137)([inf]-[1/5])
# -1Matrix(353 -229 390 -253)([inf]-[2/5])
# -1Matrix(439 -105 485 -116)([inf]-[1/5])
# -1Matrix(86 -67 95 -74)([inf]-[3/5])
# -1Matrix(77 -29 85 -32)([inf]-[1/5])
# -1Matrix(68 -39 75 -43)([inf]-[2/5])
# -1Matrix(59 -10 65 -11)([inf]-[1/5])
# -1Matrix(9 -1 10 -1)([inf]-[1/5])
# -1Matrix(4 -1 5 -1)([inf]-[1/5])
