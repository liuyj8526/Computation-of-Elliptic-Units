# %%
"""To initialize, specify:
p: prime for the p-adic calculations.
N: Defines the unit used for computation. In this code we implemented the units
    N=4     - [4]-3[2]+2[1]
    N is prime>3 - [N]-N[1]
M: p-adic precision. Ideally this value is at least 100.
"""
p = 3
N = 7
M = 100

# %run Miscellaneous.ipynb
S = Qp(p, prec = 2*M+1, type = 'capped-rel', print_mode = 'series')	#Defines the padic ring of rationals, with specified precision.
R.<y> = PowerSeriesRing(S, sparse=True)	#Allows us to write polynomials in y with coefficients in S.

"""Checks to see if a file exists with the necessary dictionaries of integrals given p, N, M
If so, loads the integrals from those files to save time.
Otherwise, runs algorithms 4_2a and 4_2b to calculate those integrals
Note that especially depending on M, this may take several hours."""

integral_1, integral_2, integral_3, integral_4 = getIntegrals(p,N,M)
# Out:
# Loading integrals from preexisting file.
# All integrals loaded.

# %%
"""Find discriminants D such that (D/p)=-1, (D/N)=1, D=1(mod 4) when N is prime and =1(mod 8) when N=4"""
Ds = getGoodDs(N,p,1000)

"""For each fundamental discriminant, calculate polynomial"""
for D in Ds:
    getPoly(D, N, integral_1, integral_2, integral_3, integral_4)
# Out:
# Output valid discriminants from 1 to 1000, for p = 3 and N = 7:
# [44, 92, 221, 284, 305, 344, 380, 428, 473, 536, 620, 632, 716, 737, 764, 869, 893, 905, 956, 989]
# Discriminant: 44
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -x^2 + 6*x*y + 2*y^2
# x^2 + 6*x*y - 2*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (7,-10,2): [499, -120, 420, -101]
# Output for BQF 7*x^2 - 10*x*y + 2*y^2:
# log_p value: 2*3 + 3^2 + 3^3 + 2*3^4 + O(3^5)
# Order of p: 4
# Order of beta: 4
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -113/3^4
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 44: X^2 - 113/81*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 92
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -2*x^2 + 6*x*y + 7*y^2
# 2*x^2 + 6*x*y - 7*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (7,6,-2): [431, 480, 1680, 1871]
# Output for BQF 7*x^2 + 6*x*y - 2*y^2:
# log_p value: 3 + 2*3^2 + 2*3^3 + 2*3^4 + O(3^5)
# Order of p: 12
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 1062686/3^12
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 92: X^2 + 1062686/531441*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 221
#
# Narrow Class Group of quadratic field K:[4]
#
# List of BQFs:
# -7*x^2 + 5*x*y + 7*y^2
# -x^2 + 13*x*y + 13*y^2
# x^2 + 13*x*y - 13*y^2
# 7*x^2 + 5*x*y - 7*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (77,-65,13): [8945, -2912, 17248, -5615]
# GammaTau for BQF (7,5,-7): [1105, 1568, 1568, 2225]
# Output for BQF 77*x^2 - 65*x*y + 13*y^2:
# log_p value: (d + 2)*3^2 + 3^3 + (d + 2)*3^4 + O(3^5)
# Order of p: 21
# Order of beta: 6
# Output for BQF 7*x^2 + 5*x*y - 7*y^2:
# log_p value: (2*d + 2)*3^2 + (d + 1)*3^4 + O(3^5)
# Order of p: 3
# Order of beta: 6
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -927839396/3^19
# Rational reconstruction for sqrtD part of coefficient: 1984663552/3^21
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1166767652582/3^24
# Rational reconstruction for sqrtD part of coefficient: -782188544/3^21
#
# Coefficients of x^3:
# Rational reconstruction for rational part of coefficient: -927839396/3^19
# Rational reconstruction for sqrtD part of coefficient: 1984663552/3^21
#
# Coefficients of x^4:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 221: X^4 + (1984663552/10460353203*sqrtD - 927839396/1162261467)*X^3 + (-782188544/10460353203*sqrtD + 1166767652582/282429536481)*X^2 + (1984663552/10460353203*sqrtD - 927839396/1162261467)*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 284
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -5*x^2 + 8*x*y + 11*y^2
# 5*x^2 + 8*x*y - 11*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (343,-124,11): [202438559, -31619280, 985946640, -153996961]
# Output for BQF 343*x^2 - 124*x*y + 11*y^2:
# log_p value: 2*3 + 3^2 + O(3^5)
# Order of p: 28
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -5542979604322/3^28
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 284: X^2 - 5542979604322/22876792454961*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 305
#
# Narrow Class Group of quadratic field K:[4]
#
# List of BQFs:
# -7*x^2 + 5*x*y + 10*y^2
# -4*x^2 + 15*x*y + 5*y^2
# 4*x^2 + 15*x*y - 5*y^2
# 7*x^2 + 5*x*y - 10*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (14,5,-5): [349, 280, 784, 629]
# GammaTau for BQF (7,5,-10): [349, 560, 392, 629]
# Output for BQF 14*x^2 + 5*x*y - 5*y^2:
# log_p value: (2*d + 1)*3 + (2*d + 2)*3^2 + (d + 1)*3^3 + 3^4 + O(3^5)
# Order of p: 7
# Order of beta: 4
# Output for BQF 7*x^2 + 5*x*y - 10*y^2:
# log_p value: (d + 1)*3 + 2*d*3^2 + (d + 1)*3^3 + (d + 2)*3^4 + O(3^5)
# Order of p: 1
# Order of beta: 4
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 8105/2*3^7
# Rational reconstruction for sqrtD part of coefficient: 173/2*3^6
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 47699/2*3^8
# Rational reconstruction for sqrtD part of coefficient: 185/2*3^6
#
# Coefficients of x^3:
# Rational reconstruction for rational part of coefficient: 8105/2*3^7
# Rational reconstruction for sqrtD part of coefficient: 173/2*3^6
#
# Coefficients of x^4:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 305: X^4 + (173/1458*sqrtD + 8105/4374)*X^3 + (185/1458*sqrtD + 47699/13122)*X^2 + (173/1458*sqrtD + 8105/4374)*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 344
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -7*x^2 + 6*x*y + 11*y^2
# 7*x^2 + 6*x*y - 11*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (7,6,-11): [7039, 12342, 7854, 13771]
# Output for BQF 7*x^2 + 6*x*y - 11*y^2:
# log_p value: 3 + 2*3^2 + 2*3^3 + 3^4 + O(3^5)
# Order of p: 4
# Order of beta: 4
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 34/3^4
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 344: X^2 + 34/81*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 380
#
# Narrow Class Group of quadratic field K:[2, 2]
#
# List of BQFs:
# -7*x^2 + 10*x*y + 10*y^2
# -5*x^2 + 10*x*y + 14*y^2
# 5*x^2 + 10*x*y - 14*y^2
# 7*x^2 + 10*x*y - 10*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (14,-10,-5): [59, 20, 56, 19]
# GammaTau for BQF (7,-10,-10): [59, 40, 28, 19]
# Output for BQF 14*x^2 - 10*x*y - 5*y^2:
# log_p value: 2*3 + 2*3^3 + 3^4 + O(3^5)
# Order of p: 11
# Order of beta: 6
# Output for BQF 7*x^2 - 10*x*y - 10*y^2:
# log_p value: 2*3 + 2*3^2 + 3^3 + 2*3^4 + O(3^5)
# Order of p: 5
# Order of beta: 6
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 0
# Rational reconstruction for sqrtD part of coefficient: -24992/3^11
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 150822542/3^16
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^3:
# Rational reconstruction for rational part of coefficient: 0
# Rational reconstruction for sqrtD part of coefficient: -24992/3^11
#
# Coefficients of x^4:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 380: X^4 - 24992/177147*sqrtD*X^3 + 150822542/43046721*X^2 - 24992/177147*sqrtD*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 428
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -7*x^2 + 8*x*y + 13*y^2
# 7*x^2 + 8*x*y - 13*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (413,-148,13): [15091855, -2326116, 73898916, -11390081]
# Output for BQF 413*x^2 - 148*x*y + 13*y^2:
# log_p value: 3^3 + O(3^5)
# Order of p: -12
# Order of beta: 4
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 762319/3^12
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 428: X^2 + 762319/531441*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 473
#
# Narrow Class Group of quadratic field K:[6]
#
# List of BQFs:
# -14*x^2 + 9*x*y + 7*y^2
# -8*x^2 + 11*x*y + 11*y^2
# -7*x^2 + 9*x*y + 14*y^2
# 7*x^2 + 9*x*y - 14*y^2
# 8*x^2 + 11*x*y - 11*y^2
# 14*x^2 + 9*x*y - 7*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (14,19,-2): [11, 16, 112, 163]
# GammaTau for BQF (322,-121,11): [571, -88, 2576, -397]
# GammaTau for BQF (7,5,-16): [67, 128, 56, 107]
# Output for BQF 14*x^2 + 19*x*y - 2*y^2:
# log_p value: (d + 2)*3^2 + 2*d*3^3 + d*3^4 + O(3^5)
# Order of p: 4
# Order of beta: 0
# Output for BQF 322*x^2 - 121*x*y + 11*y^2:
# log_p value: (2*d + 2)*3 + (2*d + 1)*3^2 + 3^4 + O(3^5)
# Order of p: -10
# Order of beta: 6
# Output for BQF 7*x^2 + 5*x*y - 16*y^2:
# log_p value: (2*d + 1)*3 + 2*3^2 + 2*3^3 + 2*d*3^4 + O(3^5)
# Order of p: -2
# Order of beta: 2
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 10496/3^9
# Rational reconstruction for sqrtD part of coefficient: 692/3^10
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1387768/3^13
# Rational reconstruction for sqrtD part of coefficient: -36836/3^14
#
# Coefficients of x^3:
# Rational reconstruction for rational part of coefficient: 20670335/3^16
# Rational reconstruction for sqrtD part of coefficient: 769472/3^15
#
# Coefficients of x^4:
# Rational reconstruction for rational part of coefficient: 1387768/3^13
# Rational reconstruction for sqrtD part of coefficient: -36836/3^14
#
# Coefficients of x^5:
# Rational reconstruction for rational part of coefficient: 10496/3^9
# Rational reconstruction for sqrtD part of coefficient: 692/3^10
#
# Coefficients of x^6:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 473: X^6 + (692/59049*sqrtD + 10496/19683)*X^5 + (-36836/4782969*sqrtD + 1387768/1594323)*X^4 + (769472/14348907*sqrtD + 20670335/43046721)*X^3 + (-36836/4782969*sqrtD + 1387768/1594323)*X^2 + (692/59049*sqrtD + 10496/19683)*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 536
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -10*x^2 + 4*x*y + 13*y^2
# 10*x^2 + 4*x*y - 13*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (434,-152,13): [1103981, -163878, 5471004, -812131]
# Output for BQF 434*x^2 - 152*x*y + 13*y^2:
# log_p value: 3 + 2*3^2 + 2*3^3 + 3^4 + O(3^5)
# Order of p: 4
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -34/3^4
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 536: X^2 - 34/81*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 620
#
# Narrow Class Group of quadratic field K:[2, 2]
#
# List of BQFs:
# -10*x^2 + 10*x*y + 13*y^2
# -5*x^2 + 20*x*y + 11*y^2
# 5*x^2 + 20*x*y - 11*y^2
# 10*x^2 + 10*x*y - 13*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (91,-68,11): [929, -220, 1820, -431]
# GammaTau for BQF (77,-68,13): [929, -260, 1540, -431]
# Output for BQF 91*x^2 - 68*x*y + 11*y^2:
# log_p value: 3 + 2*3^2 + 2*3^3 + 3^4 + O(3^5)
# Order of p: 13
# Order of beta: 2
# Output for BQF 77*x^2 - 68*x*y + 13*y^2:
# log_p value: 2*3 + 3^3 + 3^4 + O(3^5)
# Order of p: 5
# Order of beta: 6
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 0
# Rational reconstruction for sqrtD part of coefficient: 71786/3^13
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 893917513/3^18
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^3:
# Rational reconstruction for rational part of coefficient: 0
# Rational reconstruction for sqrtD part of coefficient: 71786/3^13
#
# Coefficients of x^4:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 620: X^4 + 71786/1594323*sqrtD*X^3 + 893917513/387420489*X^2 + 71786/1594323*sqrtD*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 632
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -11*x^2 + 4*x*y + 14*y^2
# 11*x^2 + 4*x*y - 14*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (7,18,-11): [2199, 6776, 4312, 13287]
# Output for BQF 7*x^2 + 18*x*y - 11*y^2:
# log_p value: 2*3 + 2*3^2 + 3^3 + O(3^5)
# Order of p: 20
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -6074010274/3^20
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 632: X^2 - 6074010274/3486784401*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 716
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -11*x^2 + 10*x*y + 14*y^2
# 11*x^2 + 10*x*y - 14*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (14,-10,-11): [48239080289299, 28871393322420, 36745409683080, 21992359087099]
# Output for BQF 14*x^2 - 10*x*y - 11*y^2:
# log_p value: 3 + 3^2 + 3^3 + O(3^5)
# Order of p: -20
# Order of beta: 4
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -2722789598/3^20
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 716: X^2 - 2722789598/3486784401*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 737
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -13*x^2 + 3*x*y + 14*y^2
# 13*x^2 + 3*x*y - 14*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (182,101,13): [-688189885, -242280168, 3391922352, 1194140651]
# Output for BQF 182*x^2 + 101*x*y + 13*y^2:
# log_p value: 2*3 + 3^2 + 3^3 + 2*3^4 + O(3^5)
# Order of p: 4
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 113/3^4
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 737: X^2 + 113/81*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 764
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -13*x^2 + 6*x*y + 14*y^2
# 13*x^2 + 6*x*y - 14*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (7,20,-13): [44721225959999, 152181699852000, 81943992228000, 278846918039999]
# Output for BQF 7*x^2 + 20*x*y - 13*y^2:
# log_p value: 3 + 2*3^3 + 2*3^4 + O(3^5)
# Order of p: 52
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 5795117153597046022417118/3^52
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 764: X^2 + 5795117153597046022417118/6461081889226673298932241*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 869
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -11*x^2 + 11*x*y + 17*y^2
# 11*x^2 + 11*x*y - 17*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (217,-125,17): [315430089598751, -69424559444800, 886184082324800, -195044612201249]
# Output for BQF 217*x^2 - 125*x*y + 17*y^2:
# log_p value: 3^2 + 2*3^3 + 3^4 + O(3^5)
# Order of p: 60
# Order of beta: 4
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -70748889263545459865344573598/3^60
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 869: X^2 - 70748889263545459865344573598/42391158275216203514294433201*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 893
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -7*x^2 + 19*x*y + 19*y^2
# 7*x^2 + 19*x*y - 19*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (7,19,-19): [2218435099, 7745999800, 2853789400, 9964434899]
# Output for BQF 7*x^2 + 19*x*y - 19*y^2:
# log_p value: O(3^5)
# Order of p: -45
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 1984895108328084801686/3^45
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 893: X^2 + 1984895108328084801686/2954312706550833698643*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 905
#
# Narrow Class Group of quadratic field K:[8]
#
# List of BQFs:
# -17*x^2 + 15*x*y + 10*y^2
# -14*x^2 + 3*x*y + 16*y^2
# -14*x^2 + 11*x*y + 14*y^2
# -10*x^2 + 15*x*y + 17*y^2
# 10*x^2 + 15*x*y - 17*y^2
# 14*x^2 + 3*x*y - 16*y^2
# 14*x^2 + 11*x*y - 14*y^2
# 17*x^2 + 15*x*y - 10*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (28,-53,17): [997, -408, 672, -275]
# GammaTau for BQF (14,3,-16): [325, 384, 336, 397]
# GammaTau for BQF (14,17,-11): [157, 264, 336, 565]
# GammaTau for BQF (7,-25,-10): [661, 240, 168, 61]
# Output for BQF 28*x^2 - 53*x*y + 17*y^2:
# log_p value: (2*d + 2)*3 + d*3^2 + (2*d + 2)*3^3 + 2*d*3^4 + O(3^5)
# Order of p: -7
# Order of beta: 6
# Output for BQF 14*x^2 + 3*x*y - 16*y^2:
# log_p value: (d + 1)*3^2 + d*3^3 + (2*d + 2)*3^4 + O(3^5)
# Order of p: -13
# Order of beta: 0
# Output for BQF 14*x^2 + 17*x*y - 11*y^2:
# log_p value: (2*d + 1)*3 + 2*d*3^2 + (2*d + 2)*3^4 + O(3^5)
# Order of p: 1
# Order of beta: 2
# Output for BQF 7*x^2 - 25*x*y - 10*y^2:
# log_p value: (d + 1)*3^2 + 3^3 + (2*d + 2)*3^4 + O(3^5)
# Order of p: -5
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 4681537/2*3^13
# Rational reconstruction for sqrtD part of coefficient: 54235/2*3^11
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 26680788119/2*3^19
# Rational reconstruction for sqrtD part of coefficient: 1186723595/2*3^20
#
# Coefficients of x^3:
# Rational reconstruction for rational part of coefficient: 5200676047009/2*3^24
# Rational reconstruction for sqrtD part of coefficient: 1043139376375/2*3^25
#
# Coefficients of x^4:
# Rational reconstruction for rational part of coefficient: 54515270640146/3^26
# Rational reconstruction for sqrtD part of coefficient: 102857840135/3^24
#
# Coefficients of x^5:
# Rational reconstruction for rational part of coefficient: 5200676047009/2*3^24
# Rational reconstruction for sqrtD part of coefficient: 1043139376375/2*3^25
#
# Coefficients of x^6:
# Rational reconstruction for rational part of coefficient: 26680788119/2*3^19
# Rational reconstruction for sqrtD part of coefficient: 1186723595/2*3^20
#
# Coefficients of x^7:
# Rational reconstruction for rational part of coefficient: 4681537/2*3^13
# Rational reconstruction for sqrtD part of coefficient: 54235/2*3^11
#
# Coefficients of x^8:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 905: X^8 + (54235/354294*sqrtD + 4681537/3188646)*X^7 + (1186723595/6973568802*sqrtD + 26680788119/2324522934)*X^6 + (1043139376375/1694577218886*sqrtD + 5200676047009/564859072962)*X^5 + (102857840135/282429536481*sqrtD + 54515270640146/2541865828329)*X^4 + (1043139376375/1694577218886*sqrtD + 5200676047009/564859072962)*X^3 + (1186723595/6973568802*sqrtD + 26680788119/2324522934)*X^2 + (54235/354294*sqrtD + 4681537/3188646)*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 956
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -10*x^2 + 14*x*y + 19*y^2
# 10*x^2 + 14*x*y - 19*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (238,-138,19): [419352889091039, -94337441214240, 1181700579420480, -265834841833441]
# Output for BQF 238*x^2 - 138*x*y + 19*y^2:
# log_p value: 3^2 + 2*3^3 + O(3^5)
# Order of p: 60
# Order of beta: 0
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: 84659281195866805682786231198/3^60
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 956: X^2 + 84659281195866805682786231198/42391158275216203514294433201*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True
#
# Discriminant: 989
#
# Narrow Class Group of quadratic field K:[2]
#
# List of BQFs:
# -5*x^2 + 23*x*y + 23*y^2
# 5*x^2 + 23*x*y - 23*y^2
#
# Representatives of classes of BQFs, augmented to N:
#
#
# GammaTau for BQF (455,-207,23): [4172278625180667, -804890452582216, 15922832866300360, -3071735448059277]
# Output for BQF 455*x^2 - 207*x*y + 23*y^2:
# log_p value: 2*3^2 + O(3^5)
# Order of p: -36
# Order of beta: 4
#
# Coefficients of 1:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x:
# Rational reconstruction for rational part of coefficient: -299691187379140958/3^36
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Coefficients of x^2:
# Rational reconstruction for rational part of coefficient: 1
# Rational reconstruction for sqrtD part of coefficient: 0
#
# Field extension L/K by characteristic Polynomial for 989: X^2 - 299691187379140958/150094635296999121*X + 1
#
# Relative discriminant of L/K is trivial: True
# L/K is a relative galois extension: True

# %% [markdown]
# #####
